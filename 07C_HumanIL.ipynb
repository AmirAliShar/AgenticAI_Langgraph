# %%
from dotenv import load_dotenv
import os
from langchain_groq import ChatGroq
load_dotenv()
GROQ_API_KEY=os.environ.get("GROQ_API_KEY")


llm =ChatGroq(model ="llama-3.3-70b-versatile")

from langchain_core.caches import InMemoryCache
from langchain_core.globals import set_llm_cache
set_llm_cache(InMemoryCache())

# %%
from langgraph.graph import StateGraph, START, END, add_messages
from langgraph.types import Command, interrupt
from typing import TypedDict, Annotated, List
from langgraph.checkpoint.memory import InMemorySaver

from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
import uuid

class State(TypedDict): 
    linkedin_topic: str
    generated_post: Annotated[List[str], add_messages]
    human_feedback: Annotated[List[str], add_messages]

def model(state: State): 
    """ Here, we're using the LLM to generate a LinkedIn post with human feedback incorporated """

    print("[model] Generating content")
    linkedin_topic = state["linkedin_topic"]
    feedback = state["human_feedback"] if "human_feedback" in state else ["No Feedback yet"]


    # Here, we define the prompt 

    prompt = f"""

        LinkedIn Topic: {linkedin_topic}
        Human Feedback: {feedback[-1] if feedback else "No feedback yet"}

        Generate a structured and well-written LinkedIn post based on the given topic.

        Consider previous human feedback to refine the reponse. 
    """

    response = llm.invoke([
        SystemMessage(content="You are an expert LinkedIn content writer"), 
        HumanMessage(content=prompt)
    ])

    geneated_linkedin_post = response.content

    print(f"[model_node] Generated post:\n{geneated_linkedin_post}\n")

    return {
       "generated_post": [AIMessage(content=geneated_linkedin_post)] , 
       "human_feedback": feedback
    }

# %%
def human_node(state: State): 
    """Human Intervention node - loops back to model unless input is done"""

    print("\n [human_node] awaiting human feedback...")

    generated_post = state["generated_post"]

    # Interrupt to get user feedback
    # Use Interrupt instead of the Input 
    user_feedback = interrupt(
        {
            "generated_post": generated_post, 
            "message": "Provide feedback or type 'done' to finish"
        }
    )

    print(f"[human_node] Received human feedback: {user_feedback}")

    # If user types "done", transition to END node
    if user_feedback.lower() == "done": 
        return Command(update={"human_feedback": state["human_feedback"] + ["Finalised"]}, goto="end_node")

    # Otherwise, update feedback and return to model for re-generation
    return Command(update={"human_feedback": state["human_feedback"] + [user_feedback]}, goto="model")

# %%
def end_node(state: State): 
    """ Final node """
    print("\n[end_node] Process finished")
    print("Final Generated Post:", state["generated_post"][-1])
    print("Final Human Feedback", state["human_feedback"])
    return {"generated_post": state["generated_post"], "human_feedback": state["human_feedback"]}

# %%
# Buiding the Graph
graph = StateGraph(State)
graph.add_node("model", model)
graph.add_node("human_node", human_node)
graph.add_node("end_node", end_node)


# Define the flow
graph.set_entry_point("model")

graph.add_edge(START, "model")
graph.add_edge("model", "human_node")

graph.set_finish_point("end_node")

# Enable Interrupt mechanism
checkpointer = InMemorySaver()
app = graph.compile(checkpointer=checkpointer)

# %%
thread_config = {"configurable": {
    "thread_id": uuid.uuid4()
}}
linkedin_topic = input("Enter your LinkedIn topic: ")
initial_state = {
    "linkedin_topic": linkedin_topic, 
    "generated_post": [], 
    "human_feedback": []
}


for chunk in app.stream(initial_state, config=thread_config):
    for node_id, value in chunk.items():
        #  If we reach an interrupt, continuously ask for human feedback

        if(node_id == "__interrupt__"):
            while True: 
                user_feedback = input("Provide feedback (or type 'done' when finished): ")

                # Resume the graph execution with the user's feedback
                app.invoke(Command(resume=user_feedback), config=thread_config)

                # Exit loop if user says done
                if user_feedback.lower() == "done":
                    break
# Out:
# [model] Generating content
# [model_node] Generated post:
# **The Rise of AI Agents: Revolutionizing Industries and Redefining the Future of Work**
#
# As we navigate the complexities of the digital age, a new era of innovation is unfolding before our eyes. The emergence of Artificial Intelligence (AI) agents is transforming the way we live, work, and interact with one another. In this post, we'll delve into the world of AI agents, exploring their capabilities, applications, and the profound impact they're having on various industries.
#
# **What are AI Agents?**
#
# AI agents refer to autonomous systems that use machine learning algorithms to perform tasks, make decisions, and interact with their environment. These intelligent agents can be programmed to execute specific functions, such as data analysis, customer service, or even creative tasks like content generation. With the ability to learn from experience and adapt to new situations, AI agents are becoming increasingly sophisticated, enabling them to tackle complex challenges and improve overall efficiency.
#
# **Industry Applications**
#
# The rise of AI agents is being felt across various sectors, including:
#
# 1. **Customer Service**: AI-powered chatbots and virtual assistants are revolutionizing the way companies interact with customers, providing 24/7 support and personalized experiences.
# 2. **Healthcare**: AI agents are being used to analyze medical images, diagnose diseases, and develop personalized treatment plans, leading to improved patient outcomes and more efficient healthcare systems.
# 3. **Finance**: AI agents are helping financial institutions detect fraud, manage risk, and optimize investment portfolios, resulting in increased accuracy and reduced costs.
# 4. **Marketing**: AI agents are enabling businesses to create targeted campaigns, predict customer behavior, and measure the effectiveness of their marketing strategies, leading to better ROI and more informed decision-making.
#
# **The Future of Work**
#
# As AI agents continue to advance, there's a growing concern about the potential impact on the job market. While it's true that automation may replace some tasks, it's also creating new opportunities for professionals to focus on high-value tasks that require creativity, empathy, and problem-solving skills. The key to success lies in upskilling and reskilling, ensuring that workers are equipped to collaborate with AI agents and leverage their capabilities to drive innovation and growth.
#
# **Conclusion**
#
# The rise of AI agents is a transformative force that's redefining the way we work, live, and interact with technology. As we move forward, it's essential to embrace this change, invest in education and training, and foster a culture of innovation and experimentation. By doing so, we can unlock the full potential of AI agents and create a brighter, more prosperous future for all.
#
# **What are your thoughts on the rise of AI agents? Share your insights, experiences, and predictions in the comments below!**
#
# #AI #ArtificialIntelligence #MachineLearning #Innovation #FutureOfWork #DigitalTransformation #IndustryTrends #Technology #Automation #CustomerService #Healthcare #Finance #Marketing #Upskilling #Reskilling #Collaboration #Growth #Innovation
#
#
#  [human_node] awaiting human feedback...
#
#  [human_node] awaiting human feedback...
# [human_node] Received human feedback: done
#
# [end_node] Process finished
# Final Generated Post: content="**The Rise of AI Agents: Revolutionizing Industries and Redefining the Future of Work**\n\nAs we navigate the complexities of the digital age, a new era of innovation is unfolding before our eyes. The emergence of Artificial Intelligence (AI) agents is transforming the way we live, work, and interact with one another. In this post, we'll delve into the world of AI agents, exploring their capabilities, applications, and the profound impact they're having on various industries.\n\n**What are AI Agents?**\n\nAI agents refer to autonomous systems that use machine learning algorithms to perform tasks, make decisions, and interact with their environment. These intelligent agents can be programmed to execute specific functions, such as data analysis, customer service, or even creative tasks like content generation. With the ability to learn from experience and adapt to new situations, AI agents are becoming increasingly sophisticated, enabling them to tackle complex challenges and improve overall efficiency.\n\n**Industry Applications**\n\nThe rise of AI agents is being felt across various sectors, including:\n\n1. **Customer Service**: AI-powered chatbots and virtual assistants are revolutionizing the way companies interact with customers, providing 24/7 support and personalized experiences.\n2. **Healthcare**: AI agents are being used to analyze medical images, diagnose diseases, and develop personalized treatment plans, leading to improved patient outcomes and more efficient healthcare systems.\n3. **Finance**: AI agents are helping financial institutions detect fraud, manage risk, and optimize investment portfolios, resulting in increased accuracy and reduced costs.\n4. **Marketing**: AI agents are enabling businesses to create targeted campaigns, predict customer behavior, and measure the effectiveness of their marketing strategies, leading to better ROI and more informed decision-making.\n\n**The Future of Work**\n\nAs AI agents continue to advance, there's a growing concern about the potential impact on the job market. While it's true that automation may replace some tasks, it's also creating new opportunities for professionals to focus on high-value tasks that require creativity, empathy, and problem-solving skills. The key to success lies in upskilling and reskilling, ensuring that workers are equipped to collaborate with AI agents and leverage their capabilities to drive innovation and growth.\n\n**Conclusion**\n\nThe rise of AI agents is a transformative force that's redefining the way we work, live, and interact with technology. As we move forward, it's essential to embrace this change, invest in education and training, and foster a culture of innovation and experimentation. By doing so, we can unlock the full potential of AI agents and create a brighter, more prosperous future for all.\n\n**What are your thoughts on the rise of AI agents? Share your insights, experiences, and predictions in the comments below!**\n\n#AI #ArtificialIntelligence #MachineLearning #Innovation #FutureOfWork #DigitalTransformation #IndustryTrends #Technology #Automation #CustomerService #Healthcare #Finance #Marketing #Upskilling #Reskilling #Collaboration #Growth #Innovation" additional_kwargs={} response_metadata={} id='bd4d7df2-dea4-4224-9aa1-a38ebbfba75b'
# Final Human Feedback [HumanMessage(content='Finalised', additional_kwargs={}, response_metadata={}, id='40396ee6-e9eb-42e1-9256-2267abb869e5')]
